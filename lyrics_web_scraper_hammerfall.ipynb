# %%
import numpy  as np
import pandas as pd
import requests
import time 
import re
from   bs4    import BeautifulSoup 
import string
import os

# %% [markdown]
# ### Send a GET request to the server.

# %%
#For other artists lyrics, just change the URL and find&replace the artist name in code!
the_artist = 'hammerfall'
URL        = 'https://www.lyrics.com/artist/Hammerfall/212623'

#Disguising as a browser. Submit headers that the script looks like a web browser
headers    = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/39.0.2171.95 Safari/537.36'}

response   = requests.get(URL, headers=headers)

print(f'Check the connection (Code 200: Get successful!):\nResponse Status Code: {response.status_code}\n')
# Out:
# Check the connection (Code 200: Get successful!):
# Response Status Code: 200

# %%
response.text[:200] #check the text roughly.
# Out:
# '<!doctype html>\n<html lang="en-US">\n<head>\n<meta name="theme-color" content="#830C66"/>\n\n<meta charset="utf-8">\n<meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1">\n<title>Hammerfall Lyrics,'

# %% [markdown]
# ### Download the artists main webpage's HTML source-code in str format and save in txt file.

# %%
# Save the file to local disks as .txt 

with open(file=f"lyrics/{the_artist}_main.txt", mode="w") as my_file:
    my_file.write(response.text)

# %%
# Read the saved file

with open(file=f"lyrics/{the_artist}_main.txt", mode="r") as file:
    the_artist_text = file.read()       #str all the text
    #text = file.readlines() #read all lines and create a list
    #text = file.readline()  #use to loop over lines

# %% [markdown]
# ### Scrap the HTML code by BeatifulSoup lib.

# %%
the_artist_soup=BeautifulSoup(markup=the_artist_text, features="html.parser")

# %% [markdown]
# #### Find raw links of song lyrics

# %%
raw_link_list = the_artist_soup.find_all(name="a", href=True)
print(f'Number of raw links: {len(raw_link_list)}')
# Out:
# Number of raw links: 738

# %% [markdown]
# #### find song links and add them in 'song_link_list'

# %%
song_link_list=[]
for link in raw_link_list:
    if link['href'].startswith('/lyric'):
        song_link_list.append("https://www.lyrics.com"+link['href'])
print(f'Number of links: {len(song_link_list)}')
# Out:
# Number of links: 458

# %% [markdown]
# #### In main page check every song pages (i) and download every page in different file

# %%
def download_songs():    
    number_songs = song_link_list
    print(f'                             ==================={len(number_songs)} songs are in process!=================== ....................................................................')
    for i, songlink in enumerate(song_link_list):
        url_link = songlink
        headers_link = {'User-agent': 'Mozilla/5.0 (X11; Linux i686; rv:2.0b10) Gecko/20100101 Firefox/4.0b10'}
        print(f'===============  Downloading from ===>{songlink}')
        response_link = requests.get(url=url_link, headers=headers_link)
        print(f'===============  Saving')

        with open(file=f"lyrics/{the_artist}/{the_artist}_lyric_{i}.txt", mode="w") as the_file:
            the_file.write(response_link.text)   
        timer=np.random.random()
        print(f'===============  Waiting {round(timer,2)} seconds - PROCESS: %{round(((i+1)/len(number_songs)),2)}')
        time.sleep(timer)  # waiting time in seconds
    print('                                     ===================FINISHED===================')

# %%
# Create folders to download artist's lyric webpages
parent_dir_path = !pwd
parent_dir_path = parent_dir_path[0]
directory = parent_dir_path + '/lyrics/' + the_artist

if os.path.exists(directory):
    print(f"The directory \'{directory}\' exists.")
else:
    os.mkdir(directory)
    print(f"The directory \'{directory}\' created.")
    download_songs()
# Out:
# The directory '/home/elendar/ds_projects/song_artist_prediction/lyrics/hammerfall' exists.

# %% [markdown]
# #### Read files and extract lyrics with song names

# %%
#pattern2 = '[<][<\w\d =\":/\.\#;]*[>]'
all_sentences          = []
song_names             = []
amount_sentences_list  = []

for i in range(len(song_link_list)): 
    print(f'{i}/{len(song_link_list)}')
    with open(file=f"lyrics/{the_artist}/{the_artist}_lyric_{i}.txt", mode="r") as file:            
        print(f'open file: {the_artist}_lyric_{i}.txt')
        the_artist_text = file.read()       #str all the text

    the_artist_soup1  = BeautifulSoup(markup = the_artist_text, features='html.parser')
    raw_ly            = the_artist_soup1.find(name='pre', attrs={'class':"lyric-body"})
    raw_song_names    = the_artist_soup1.find(name='h1', attrs={'class':'lyric-title', 'id':"lyric-title-text"})
    
    if raw_ly is None:
        print('Empty page is detected!!! Continuing to next page!')
        continue
        
    ly = raw_ly.get_text()
    ly = ly.lower()
    ly = re.sub('\n\n','\n', ly)
    ly = ly.replace('-', ' ')
    #print([ch for ch in ly if ch not in string.punctuation])
    ly="".join([ch for ch in ly if ch not in string.punctuation]) # if string.punctuation gives all characters that i want to take out
    ly = re.split('\n', ly)                                       # check all characters in ly, if they are not in special 
                                                                  # characters join them together
    if len(ly) < 3:
        print('Empty page is detected!!! Continuing to next page!')
        continue
        
    all_sentences.extend(ly)
    print(f'Song name: {raw_song_names.get_text()}..............has {len(ly)} lines')
    for k in range(len(ly)):
        song_names.append(raw_song_names.get_text())
# Out:
# 0/458
# open file: hammerfall_lyric_0.txt
# Song name: Hector's Hymn..............has 34 lines
# 1/458
# open file: hammerfall_lyric_1.txt
# Song name: Heeding the Call..............has 28 lines
# 2/458
# open file: hammerfall_lyric_2.txt
# Song name: Any Means Necessary..............has 42 lines
# 3/458
# open file: hammerfall_lyric_3.txt
# Song name: Riders of the Storm..............has 31 lines
# 4/458
# open file: hammerfall_lyric_4.txt
# Song name: Crimson Thunder..............has 26 lines
# 5/458
# open file: hammerfall_lyric_5.txt
# Song name: Renegade..............has 34 lines
# 6/458
# open file: hammerfall_lyric_6.txt
# Song name: Blood Bound..............has 44 lines
# 7/458
# open file: hammerfall_lyric_7.txt
# Song name: Last Man Standing..............has 63 lines
# 8/458
# open file: hammerfall_lyric_8.txt
# Song name: Fury of the Wild..............has 30 lines
# 9/458
# open file: hammerfall_lyric_9.txt
# Song name: Always Will Be..............has 31 lines
# 10/458
# open file: hammerfall_lyric_10.txt
# Song name: Steel Meets Steel..............has 17 lines
# 11/458
# open file: hammerfall_lyric_11.txt
# Song name: The Dragon Lies Bleeding..............has 36 lines
# 12/458
# open file: hammerfall_lyric_12.txt
# Song name: Let the Hammer Fall..............has 24 lines
# 13/458
# open file: hammerfall_lyric_13.txt
# Song name: The Templar Flame..............has 28 lines
# 14/458
# open file: hammerfall_lyric_14.txt
# Song name: Glory To the Brave..............has 34 lines
# 15/458
# open file: hammerfall_lyric_15.txt
# Song name: One More Time..............has 41 lines
# 16/458
# open file: hammerfall_lyric_16.txt
# Song name: Hammerfall..............has 26 lines
# 17/458
# open file: hammerfall_lyric_17.txt
# Song name: Threshold..............has 33 lines
# 18/458
# open file: hammerfall_lyric_18.txt
# Song name: Hearts On Fire..............has 35 lines
# 19/458
# open file: hammerfall_lyric_19.txt
# Song name: Last Man Standing..............has 63 lines
# 20/458
# open file: hammerfall_lyric_20.txt
# Song name: Hearts on Fire..............has 35 lines
# 21/458
# open file: hammerfall_lyric_21.txt
# Song name: One More Time..............has 41 lines
# 22/458
# open file: hammerfall_lyric_22.txt
# Song name: Any Meansnecessary..............has 42 lines
# 23/458
# open file: hammerfall_lyric_23.txt
# Song name: Life as Now..............has 5 lines
# 24/458
# open file: hammerfall_lyric_24.txt
# Song name: Between Two Worlds..............has 26 lines
# 25/458
# open file: hammerfall_lyric_25.txt
# Empty page is detected!!! Continuing to next page!
# 26/458
# open file: hammerfall_lyric_26.txt
# Song name: Any Means Necessary..............has 42 lines
# 27/458
# open file: hammerfall_lyric_27.txt
# Song name: Punish And Enslave..............has 81 lines
# 28/458
# open file: hammerfall_lyric_28.txt
# Song name: Legion..............has 31 lines
# 29/458
# open file: hammerfall_lyric_29.txt
# Song name: Between Two Worlds..............has 26 lines
# 30/458
# open file: hammerfall_lyric_30.txt
# Song name: No Sacrifice No Victory..............has 24 lines
# 31/458
# open file: hammerfall_lyric_31.txt
# Song name: Bring The Hammer Down..............has 32 lines
# 32/458
# open file: hammerfall_lyric_32.txt
# Song name: One Of A Kind..............has 37 lines
# 33/458
# open file: hammerfall_lyric_33.txt
# Empty page is detected!!! Continuing to next page!
# 34/458
# open file: hammerfall_lyric_34.txt
# Song name: Last Man Standing..............has 63 lines
# 35/458
# open file: hammerfall_lyric_35.txt
# Song name: The Dragon Lies Bleeding..............has 36 lines
# 36/458
# open file: hammerfall_lyric_36.txt
# Song name: Child of the Damned..............has 21 lines
# 37/458
# open file: hammerfall_lyric_37.txt
# Song name: Eternal Dark..............has 24 lines
# 38/458
# open file: hammerfall_lyric_38.txt
# Song name: I Want Out..............has 31 lines
# 39/458
# open file: hammerfall_lyric_39.txt
# Song name: Man on the Silver Mountain..............has 41 lines
# 40/458
# open file: hammerfall_lyric_40.txt
# Empty page is detected!!! Continuing to next page!
# 41/458
# open file: hammerfall_lyric_41.txt
# Song name: Run With the Devil..............has 42 lines
# 42/458
# open file: hammerfall_lyric_42.txt
# Song name: We're Gonna Make It..............has 23 lines
# 43/458
# open file: hammerfall_lyric_43.txt
# Song name: Breaking the Law..............has 22 lines
# 44/458
# open file: hammerfall_lyric_44.txt
# Song name: Angel of Mercy..............has 27 lines
# 45/458
# open file: hammerfall_lyric_45.txt
# Song name: Detroit Rock City..............has 41 lines
# 46/458
# open file: hammerfall_lyric_46.txt
# Song name: Youth Gone Wild..............has 45 lines
# 47/458
# open file: hammerfall_lyric_47.txt
# Song name: Last Man Standing [DVD]..............has 63 lines
# 48/458
# open file: hammerfall_lyric_48.txt
# Song name: Child of the Damned..............has 21 lines
# 49/458
# open file: hammerfall_lyric_49.txt
# Empty page is detected!!! Continuing to next page!
# 50/458
# open file: hammerfall_lyric_50.txt
# Song name: Eternal Dark..............has 24 lines
# 51/458
# open file: hammerfall_lyric_51.txt
# Empty page is detected!!! Continuing to next page!
# 52/458
# open file: hammerfall_lyric_52.txt
# Song name: I Want Out..............has 31 lines
# 53/458
# open file: hammerfall_lyric_53.txt
# Song name: Man on the Silver Mountain..............has 41 lines
# 54/458
# open file: hammerfall_lyric_54.txt
# Empty page is detected!!! Continuing to next page!
# 55/458
# open file: hammerfall_lyric_55.txt
# Song name: Run With the Devil..............has 42 lines
# 56/458
# open file: hammerfall_lyric_56.txt
# Song name: We're Gonna Make It..............has 23 lines
# 57/458
# open file: hammerfall_lyric_57.txt
# Song name: Breaking the Law..............has 22 lines
# 58/458
# open file: hammerfall_lyric_58.txt
# Song name: Angel of Mercy..............has 27 lines
# 59/458
# open file: hammerfall_lyric_59.txt
# Song name: Detroit Rock City..............has 41 lines
# 60/458
# open file: hammerfall_lyric_60.txt
# Song name: Crazy Nights..............has 40 lines
# 61/458
# open file: hammerfall_lyric_61.txt
# Song name: The Fire Burns Forever..............has 28 lines
# 62/458
# open file: hammerfall_lyric_62.txt
# Song name: Last Man Standing..............has 63 lines
# 63/458
# open file: hammerfall_lyric_63.txt
# Song name: Restless Soul..............has 40 lines
# 64/458
# open file: hammerfall_lyric_64.txt
# Song name: Heeding the Call..............has 28 lines
# 65/458
# open file: hammerfall_lyric_65.txt
# Song name: Renegade..............has 34 lines
# 66/458
# open file: hammerfall_lyric_66.txt
# Song name: Hearts on Fire..............has 35 lines
# 67/458
# open file: hammerfall_lyric_67.txt
# Song name: Blood Bound..............has 44 lines
# 68/458
# open file: hammerfall_lyric_68.txt
# Song name: Natural High..............has 29 lines
# 69/458
# open file: hammerfall_lyric_69.txt
# Song name: Genocide..............has 27 lines
# 70/458
# open file: hammerfall_lyric_70.txt
# Song name: Hammerfall..............has 23 lines
# 71/458
# open file: hammerfall_lyric_71.txt
# Song name: Genocide..............has 28 lines
# 72/458
# open file: hammerfall_lyric_72.txt
# Song name: Hearts on Fire [*]..............has 35 lines
# 73/458
# open file: hammerfall_lyric_73.txt
# Song name: Threshold..............has 33 lines
# 74/458
# open file: hammerfall_lyric_74.txt
# Song name: Dark Wings, Dark Words..............has 37 lines
# 75/458
# open file: hammerfall_lyric_75.txt
# Song name: Hammerfall..............has 26 lines
# 76/458
# open file: hammerfall_lyric_76.txt
# Song name: Last Man Standing [#]..............has 63 lines
# 77/458
# open file: hammerfall_lyric_77.txt
# Song name: Last Man Standing [Mix]..............has 63 lines
# 78/458
# open file: hammerfall_lyric_78.txt
# Song name: Hammerfall V2.0. 07 [#]..............has 23 lines
# 79/458
# open file: hammerfall_lyric_79.txt
# Song name: The Dragon Lies Bleeding..............has 36 lines
# 80/458
# open file: hammerfall_lyric_80.txt
# Song name: Steel Meets Steel..............has 17 lines
# 81/458
# open file: hammerfall_lyric_81.txt
# Song name: Glory to the Brave..............has 34 lines
# 82/458
# open file: hammerfall_lyric_82.txt
# Song name: Heeding the Call..............has 28 lines
# 83/458
# open file: hammerfall_lyric_83.txt
# Song name: At the End of the Rainbow..............has 39 lines
# 84/458
# open file: hammerfall_lyric_84.txt
# Song name: Legacy of Kings..............has 36 lines
# 85/458
# open file: hammerfall_lyric_85.txt
# Song name: Let the Hammer Fall [Live]..............has 24 lines
# 86/458
# open file: hammerfall_lyric_86.txt
# Song name: Templars of Steel..............has 31 lines
# 87/458
# open file: hammerfall_lyric_87.txt
# Song name: Renegade..............has 34 lines
# 88/458
# open file: hammerfall_lyric_88.txt
# Song name: Always Will Be..............has 31 lines
# 89/458
# open file: hammerfall_lyric_89.txt
# Song name: Keep the Flame Burning..............has 22 lines
# 90/458
# open file: hammerfall_lyric_90.txt
# Song name: Riders of the Storm..............has 31 lines
# 91/458
# open file: hammerfall_lyric_91.txt
# Song name: Hearts on Fire..............has 35 lines
# 92/458
# open file: hammerfall_lyric_92.txt
# Song name: Crimson Thunder..............has 26 lines
# 93/458
# open file: hammerfall_lyric_93.txt
# Song name: Hero's Return..............has 32 lines
# 94/458
# open file: hammerfall_lyric_94.txt
# Song name: Blood Bound..............has 44 lines
# 95/458
# open file: hammerfall_lyric_95.txt
# Song name: Secrets..............has 36 lines
# 96/458
# open file: hammerfall_lyric_96.txt
# Song name: Fury of the Wild..............has 30 lines
# 97/458
# open file: hammerfall_lyric_97.txt
# Song name: Never, Ever..............has 26 lines
# 98/458
# open file: hammerfall_lyric_98.txt
# Song name: Threshold..............has 33 lines
# 99/458
# open file: hammerfall_lyric_99.txt
# Song name: Natural High..............has 29 lines
# 100/458
# open file: hammerfall_lyric_100.txt
# Song name: Dark Wings, Dark Words..............has 37 lines
# 101/458
# open file: hammerfall_lyric_101.txt
# Song name: The Fire Burns Forever..............has 29 lines
# 102/458
# open file: hammerfall_lyric_102.txt
# Song name: Restless Soul [#]..............has 40 lines
# 103/458
# open file: hammerfall_lyric_103.txt
# Song name: The Metal Age [Live][*]..............has 29 lines
# 104/458
# open file: hammerfall_lyric_104.txt
# Song name: Stone Cold [Live][*]..............has 16 lines
# 105/458
# open file: hammerfall_lyric_105.txt
# Song name: Hammerfall V2.0. 07 [Rough Mix Version][*][Multimedia Track]..............has 23 lines
# 106/458
# open file: hammerfall_lyric_106.txt
# Song name: Legacy of Kings..............has 36 lines
# 107/458
# open file: hammerfall_lyric_107.txt
# Song name: Detroit Rock City..............has 41 lines
# 108/458
# open file: hammerfall_lyric_108.txt
# Song name: Heeding the Call..............has 28 lines
# 109/458
# open file: hammerfall_lyric_109.txt
# Song name: Eternal Dark..............has 24 lines
# 110/458
# open file: hammerfall_lyric_110.txt
# Song name: Natural High..............has 29 lines
# 111/458
# open file: hammerfall_lyric_111.txt
# Song name: Natural High..............has 29 lines
# 112/458
# open file: hammerfall_lyric_112.txt
# Song name: Natural High..............has 29 lines
# 113/458
# open file: hammerfall_lyric_113.txt
# Song name: Fire Burns Forever..............has 29 lines
# 114/458
# open file: hammerfall_lyric_114.txt
# Song name: Natural High (Video)..............has 29 lines
# 115/458
# open file: hammerfall_lyric_115.txt
# Song name: Ravenlord..............has 23 lines
# 116/458
# open file: hammerfall_lyric_116.txt
# Song name: Natural High..............has 29 lines
# 117/458
# open file: hammerfall_lyric_117.txt
# Song name: This Fire Burns Forever..............has 29 lines
# 118/458
# open file: hammerfall_lyric_118.txt
# Song name: Threshold..............has 33 lines
# 119/458
# open file: hammerfall_lyric_119.txt
# Song name: The Fire Burns Forever..............has 29 lines
# 120/458
# open file: hammerfall_lyric_120.txt
# Song name: Rebel Inside..............has 45 lines
# 121/458
# open file: hammerfall_lyric_121.txt
# Song name: Natural High..............has 29 lines
# 122/458
# open file: hammerfall_lyric_122.txt
# Song name: Dark Wings, Dark Words..............has 37 lines
# 123/458
# open file: hammerfall_lyric_123.txt
# Song name: Howlin' with the 'Pac..............has 34 lines
# 124/458
# open file: hammerfall_lyric_124.txt
# Song name: Shadow Empire..............has 42 lines
# 125/458
# open file: hammerfall_lyric_125.txt
# Song name: Carved in Stone..............has 33 lines
# 126/458
# open file: hammerfall_lyric_126.txt
# Empty page is detected!!! Continuing to next page!
# 127/458
# open file: hammerfall_lyric_127.txt
# Song name: Genocide..............has 28 lines
# 128/458
# open file: hammerfall_lyric_128.txt
# Song name: Titan..............has 42 lines
# 129/458
# open file: hammerfall_lyric_129.txt
# Song name: Threshold..............has 33 lines
# 130/458
# open file: hammerfall_lyric_130.txt
# Song name: Fire Burns Forever..............has 29 lines
# 131/458
# open file: hammerfall_lyric_131.txt
# Song name: Rebel Inside..............has 45 lines
# 132/458
# open file: hammerfall_lyric_132.txt
# Song name: Natural High..............has 29 lines
# 133/458
# open file: hammerfall_lyric_133.txt
# Song name: Dark Wings, Dark Words..............has 37 lines
# 134/458
# open file: hammerfall_lyric_134.txt
# Song name: Howlin' with the 'Pac..............has 34 lines
# 135/458
# open file: hammerfall_lyric_135.txt
# Song name: Shadow Empire..............has 42 lines
# 136/458
# open file: hammerfall_lyric_136.txt
# Song name: Carved in Stone..............has 33 lines
# 137/458
# open file: hammerfall_lyric_137.txt
# Song name: Genocide..............has 28 lines
# 138/458
# open file: hammerfall_lyric_138.txt
# Song name: Titan..............has 42 lines
# 139/458
# open file: hammerfall_lyric_139.txt
# Song name: Threshold..............has 33 lines
# 140/458
# open file: hammerfall_lyric_140.txt
# Song name: The Fire Burns Forever..............has 29 lines
# 141/458
# open file: hammerfall_lyric_141.txt
# Song name: Fire Burns Forever..............has 29 lines
# 142/458
# open file: hammerfall_lyric_142.txt
# Song name: Rebel Inside..............has 45 lines
# 143/458
# open file: hammerfall_lyric_143.txt
# Song name: Natural High..............has 29 lines
# 144/458
# open file: hammerfall_lyric_144.txt
# Song name: Dark Wings, Dark Words..............has 37 lines
# 145/458
# open file: hammerfall_lyric_145.txt
# Song name: Howlin' With the 'Pac..............has 34 lines
# 146/458
# open file: hammerfall_lyric_146.txt
# Song name: Shadow Empire..............has 42 lines
# 147/458
# open file: hammerfall_lyric_147.txt
# Song name: Carved in Stone..............has 33 lines
# 148/458
# open file: hammerfall_lyric_148.txt
# Song name: Genocide..............has 28 lines
# 149/458
# open file: hammerfall_lyric_149.txt
# Song name: Titan..............has 42 lines
# 150/458
# open file: hammerfall_lyric_150.txt
# Empty page is detected!!! Continuing to next page!
# 151/458
# open file: hammerfall_lyric_151.txt
# Empty page is detected!!! Continuing to next page!
# 152/458
# open file: hammerfall_lyric_152.txt
# Song name: Secrets..............has 36 lines
# 153/458
# open file: hammerfall_lyric_153.txt
# Song name: Blood Bound..............has 44 lines
# 154/458
# open file: hammerfall_lyric_154.txt
# Song name: Fury of the Wild..............has 30 lines
# 155/458
# open file: hammerfall_lyric_155.txt
# Song name: Hammer of Justice..............has 46 lines
# 156/458
# open file: hammerfall_lyric_156.txt
# Song name: Never, Ever..............has 26 lines
# 157/458
# open file: hammerfall_lyric_157.txt
# Song name: Born to Rule..............has 32 lines
# 158/458
# open file: hammerfall_lyric_158.txt
# Song name: The Templar Flame..............has 28 lines
# 159/458
# open file: hammerfall_lyric_159.txt
# Empty page is detected!!! Continuing to next page!
# 160/458
# open file: hammerfall_lyric_160.txt
# Song name: Take the Black..............has 49 lines
# 161/458
# open file: hammerfall_lyric_161.txt
# Song name: Knights of the 21st Century..............has 45 lines
# 162/458
# open file: hammerfall_lyric_162.txt
# Song name: Secrets..............has 36 lines
# 163/458
# open file: hammerfall_lyric_163.txt
# Song name: Blood Bound..............has 44 lines
# 164/458
# open file: hammerfall_lyric_164.txt
# Song name: Fury of the Wild..............has 30 lines
# 165/458
# open file: hammerfall_lyric_165.txt
# Song name: Hammer of Justice..............has 46 lines
# 166/458
# open file: hammerfall_lyric_166.txt
# Song name: Never, Ever..............has 26 lines
# 167/458
# open file: hammerfall_lyric_167.txt
# Song name: Born to Rule..............has 32 lines
# 168/458
# open file: hammerfall_lyric_168.txt
# Song name: Templar Flame..............has 28 lines
# 169/458
# open file: hammerfall_lyric_169.txt
# Empty page is detected!!! Continuing to next page!
# 170/458
# open file: hammerfall_lyric_170.txt
# Song name: Take the Black..............has 49 lines
# 171/458
# open file: hammerfall_lyric_171.txt
# Song name: Knights of the 21st Century..............has 45 lines
# 172/458
# open file: hammerfall_lyric_172.txt
# Song name: Metal Age..............has 29 lines
# 173/458
# open file: hammerfall_lyric_173.txt
# Song name: Riders of the Storm..............has 31 lines
# 174/458
# open file: hammerfall_lyric_174.txt
# Song name: Blood Bound..............has 44 lines
# 175/458
# open file: hammerfall_lyric_175.txt
# Song name: Renegade [DVD]..............has 34 lines
# 176/458
# open file: hammerfall_lyric_176.txt
# Song name: Blood Bound..............has 44 lines
# 177/458
# open file: hammerfall_lyric_177.txt
# Empty page is detected!!! Continuing to next page!
# 178/458
# open file: hammerfall_lyric_178.txt
# Song name: Riders of the Storm..............has 31 lines
# 179/458
# open file: hammerfall_lyric_179.txt
# Song name: Heeding the Call..............has 28 lines
# 180/458
# open file: hammerfall_lyric_180.txt
# Song name: Stone Cold..............has 16 lines
# 181/458
# open file: hammerfall_lyric_181.txt
# Song name: Hero's Return..............has 32 lines
# 182/458
# open file: hammerfall_lyric_182.txt
# Song name: Legacy of Kings..............has 36 lines
# 183/458
# open file: hammerfall_lyric_183.txt
# Song name: At the End of the Rainbow..............has 39 lines
# 184/458
# open file: hammerfall_lyric_184.txt
# Song name: The Way of the Warrior..............has 47 lines
# 185/458
# open file: hammerfall_lyric_185.txt
# Song name: The Unforgiving Blade..............has 27 lines
# 186/458
# open file: hammerfall_lyric_186.txt
# Song name: Glory to the Brave..............has 34 lines
# 187/458
# open file: hammerfall_lyric_187.txt
# Song name: Let the Hammer Fall..............has 24 lines
# 188/458
# open file: hammerfall_lyric_188.txt
# Song name: Renegade..............has 34 lines
# 189/458
# open file: hammerfall_lyric_189.txt
# Song name: Steel Meets Steel..............has 17 lines
# 190/458
# open file: hammerfall_lyric_190.txt
# Song name: Crimson Thunder..............has 26 lines
# 191/458
# open file: hammerfall_lyric_191.txt
# Song name: Templars of Steel..............has 31 lines
# 192/458
# open file: hammerfall_lyric_192.txt
# Song name: Hearts on Fire..............has 35 lines
# 193/458
# open file: hammerfall_lyric_193.txt
# Song name: Hammerfall..............has 26 lines
# 194/458
# open file: hammerfall_lyric_194.txt
# Song name: The Dragon Lies Bleeding [*]..............has 36 lines
# 195/458
# open file: hammerfall_lyric_195.txt
# Song name: Stronger Than All [*]..............has 30 lines
# 196/458
# open file: hammerfall_lyric_196.txt
# Song name: A Legend Reborn [*]..............has 33 lines
# 197/458
# open file: hammerfall_lyric_197.txt
# Empty page is detected!!! Continuing to next page!
# 198/458
# open file: hammerfall_lyric_198.txt
# Song name: Riders of the Storm..............has 31 lines
# 199/458
# open file: hammerfall_lyric_199.txt
# Song name: Heeding the Call..............has 28 lines
# 200/458
# open file: hammerfall_lyric_200.txt
# Song name: Stone Cold..............has 16 lines
# 201/458
# open file: hammerfall_lyric_201.txt
# Song name: Hero's Return..............has 32 lines
# 202/458
# open file: hammerfall_lyric_202.txt
# Song name: Legacy of Kings..............has 36 lines
# 203/458
# open file: hammerfall_lyric_203.txt
# Empty page is detected!!! Continuing to next page!
# 204/458
# open file: hammerfall_lyric_204.txt
# Song name: At the End of the Rainbow..............has 39 lines
# 205/458
# open file: hammerfall_lyric_205.txt
# Song name: The Way of the Warrior..............has 47 lines
# 206/458
# open file: hammerfall_lyric_206.txt
# Song name: The Unforgiving Blade..............has 27 lines
# 207/458
# open file: hammerfall_lyric_207.txt
# Song name: Glory to the Brave..............has 34 lines
# 208/458
# open file: hammerfall_lyric_208.txt
# Empty page is detected!!! Continuing to next page!
# 209/458
# open file: hammerfall_lyric_209.txt
# Song name: Let the Hammer Fall..............has 24 lines
# 210/458
# open file: hammerfall_lyric_210.txt
# Song name: Renegade..............has 34 lines
# 211/458
# open file: hammerfall_lyric_211.txt
# Song name: Steel Meets Steel..............has 17 lines
# 212/458
# open file: hammerfall_lyric_212.txt
# Song name: Crimson Thunder..............has 26 lines
# 213/458
# open file: hammerfall_lyric_213.txt
# Song name: Templars of Steel..............has 31 lines
# 214/458
# open file: hammerfall_lyric_214.txt
# Song name: Hearts on Fire..............has 35 lines
# 215/458
# open file: hammerfall_lyric_215.txt
# Song name: Legacy Of Kings..............has 36 lines
# 216/458
# open file: hammerfall_lyric_216.txt
# Song name: Dreams Come True..............has 30 lines
# 217/458
# open file: hammerfall_lyric_217.txt
# Song name: Hearts on Fire..............has 35 lines
# 218/458
# open file: hammerfall_lyric_218.txt
# Song name: Riders of the Storm..............has 31 lines
# 219/458
# open file: hammerfall_lyric_219.txt
# Song name: Hearts on Fire..............has 35 lines
# 220/458
# open file: hammerfall_lyric_220.txt
# Song name: On the Edge of Honour..............has 28 lines
# 221/458
# open file: hammerfall_lyric_221.txt
# Song name: Crimson Thunder..............has 26 lines
# 222/458
# open file: hammerfall_lyric_222.txt
# Empty page is detected!!! Continuing to next page!
# 223/458
# open file: hammerfall_lyric_223.txt
# Song name: Trailblazers..............has 32 lines
# 224/458
# open file: hammerfall_lyric_224.txt
# Song name: Dreams Come True..............has 30 lines
# 225/458
# open file: hammerfall_lyric_225.txt
# Song name: Angel of Mercy..............has 27 lines
# 226/458
# open file: hammerfall_lyric_226.txt
# Song name: The Unforgiving Blade..............has 27 lines
# 227/458
# open file: hammerfall_lyric_227.txt
# Song name: Unforgiving Blade..............has 27 lines
# 228/458
# open file: hammerfall_lyric_228.txt
# Empty page is detected!!! Continuing to next page!
# 229/458
# open file: hammerfall_lyric_229.txt
# Song name: Hero's Return..............has 32 lines
# 230/458
# open file: hammerfall_lyric_230.txt
# Song name: Heros Return..............has 32 lines
# 231/458
# open file: hammerfall_lyric_231.txt
# Song name: Detroit Rock City [*]..............has 41 lines
# 232/458
# open file: hammerfall_lyric_232.txt
# Song name: Riders of the Storm..............has 31 lines
# 233/458
# open file: hammerfall_lyric_233.txt
# Song name: Hearts on Fire..............has 35 lines
# 234/458
# open file: hammerfall_lyric_234.txt
# Song name: On the Edge of Honour..............has 28 lines
# 235/458
# open file: hammerfall_lyric_235.txt
# Song name: Crimson Thunder..............has 26 lines
# 236/458
# open file: hammerfall_lyric_236.txt
# Empty page is detected!!! Continuing to next page!
# 237/458
# open file: hammerfall_lyric_237.txt
# Song name: Trail Blazers..............has 32 lines
# 238/458
# open file: hammerfall_lyric_238.txt
# Song name: Dreams Come True..............has 30 lines
# 239/458
# open file: hammerfall_lyric_239.txt
# Song name: Angel of Mercy..............has 27 lines
# 240/458
# open file: hammerfall_lyric_240.txt
# Song name: The Unforgiving Blade..............has 27 lines
# 241/458
# open file: hammerfall_lyric_241.txt
# Empty page is detected!!! Continuing to next page!
# 242/458
# open file: hammerfall_lyric_242.txt
# Song name: Hero's Return..............has 32 lines
# 243/458
# open file: hammerfall_lyric_243.txt
# Song name: Crazy Nights [*]..............has 40 lines
# 244/458
# open file: hammerfall_lyric_244.txt
# Song name: Renegade [*]..............has 34 lines
# 245/458
# open file: hammerfall_lyric_245.txt
# Song name: Hammerfall [*]..............has 23 lines
# 246/458
# open file: hammerfall_lyric_246.txt
# Song name: Riders of the Storm..............has 31 lines
# 247/458
# open file: hammerfall_lyric_247.txt
# Song name: Hearts on Fire..............has 35 lines
# 248/458
# open file: hammerfall_lyric_248.txt
# Song name: On the Edge of Honour..............has 28 lines
# 249/458
# open file: hammerfall_lyric_249.txt
# Song name: Crimson Thunder..............has 26 lines
# 250/458
# open file: hammerfall_lyric_250.txt
# Empty page is detected!!! Continuing to next page!
# 251/458
# open file: hammerfall_lyric_251.txt
# Song name: Trailblazers..............has 32 lines
# 252/458
# open file: hammerfall_lyric_252.txt
# Song name: Dreams Come True..............has 30 lines
# 253/458
# open file: hammerfall_lyric_253.txt
# Song name: Angel of Mercy..............has 27 lines
# 254/458
# open file: hammerfall_lyric_254.txt
# Song name: The Unforgiving Blade..............has 27 lines
# 255/458
# open file: hammerfall_lyric_255.txt
# Empty page is detected!!! Continuing to next page!
# 256/458
# open file: hammerfall_lyric_256.txt
# Song name: Heros Return..............has 32 lines
# 257/458
# open file: hammerfall_lyric_257.txt
# Song name: Crazy Nights [Bonus Track for Japan]..............has 40 lines
# 258/458
# open file: hammerfall_lyric_258.txt
# Song name: Renegade [Bonus Track for Japan]..............has 34 lines
# 259/458
# open file: hammerfall_lyric_259.txt
# Song name: Hammerfall [Bonus Track for Japan]..............has 23 lines
# 260/458
# open file: hammerfall_lyric_260.txt
# Song name: Hearts on Fire..............has 35 lines
# 261/458
# open file: hammerfall_lyric_261.txt
# Song name: Hearts on Fire..............has 35 lines
# 262/458
# open file: hammerfall_lyric_262.txt
# Song name: We're Gonna Make It..............has 23 lines
# 263/458
# open file: hammerfall_lyric_263.txt
# Song name: Heeding the Call..............has 28 lines
# 264/458
# open file: hammerfall_lyric_264.txt
# Song name: Heeding the Call [Bonus CD-ROM][Multimedia Track]..............has 28 lines
# 265/458
# open file: hammerfall_lyric_265.txt
# Song name: The Dragon Lies Bleeding..............has 36 lines
# 266/458
# open file: hammerfall_lyric_266.txt
# Song name: Steel Meets Steel..............has 17 lines
# 267/458
# open file: hammerfall_lyric_267.txt
# Song name: Fallen One..............has 29 lines
# 268/458
# open file: hammerfall_lyric_268.txt
# Song name: Always Will Be [Acoustic]..............has 31 lines
# 269/458
# open file: hammerfall_lyric_269.txt
# Song name: Always Will Be..............has 31 lines
# 270/458
# open file: hammerfall_lyric_270.txt
# Song name: We're Gonna Make It..............has 23 lines
# 271/458
# open file: hammerfall_lyric_271.txt
# Song name: We're Gonna Make It..............has 23 lines
# 272/458
# open file: hammerfall_lyric_272.txt
# Song name: Renegade..............has 34 lines
# 273/458
# open file: hammerfall_lyric_273.txt
# Song name: Man on the Silver Mountain..............has 41 lines
# 274/458
# open file: hammerfall_lyric_274.txt
# Song name: Run With the Devil..............has 42 lines
# 275/458
# open file: hammerfall_lyric_275.txt
# Song name: Templars of Steel..............has 31 lines
# 276/458
# open file: hammerfall_lyric_276.txt
# Song name: Keep the Flame Burning..............has 22 lines
# 277/458
# open file: hammerfall_lyric_277.txt
# Song name: Renegade..............has 34 lines
# 278/458
# open file: hammerfall_lyric_278.txt
# Song name: Living in Victory..............has 37 lines
# 279/458
# open file: hammerfall_lyric_279.txt
# Song name: Always Will Be..............has 31 lines
# 280/458
# open file: hammerfall_lyric_280.txt
# Song name: The Way of the Warrior..............has 47 lines
# 281/458
# open file: hammerfall_lyric_281.txt
# Song name: Destined for Glory..............has 46 lines
# 282/458
# open file: hammerfall_lyric_282.txt
# Song name: The Champion..............has 43 lines
# 283/458
# open file: hammerfall_lyric_283.txt
# Empty page is detected!!! Continuing to next page!
# 284/458
# open file: hammerfall_lyric_284.txt
# Song name: A Legend Reborn..............has 33 lines
# 285/458
# open file: hammerfall_lyric_285.txt
# Empty page is detected!!! Continuing to next page!
# 286/458
# open file: hammerfall_lyric_286.txt
# Empty page is detected!!! Continuing to next page!
# 287/458
# open file: hammerfall_lyric_287.txt
# Song name: Legacy of Kings..............has 36 lines
# 288/458
# open file: hammerfall_lyric_288.txt
# Song name: I Want Out..............has 31 lines
# 289/458
# open file: hammerfall_lyric_289.txt
# Song name: At the End of the Rainbow..............has 39 lines
# 290/458
# open file: hammerfall_lyric_290.txt
# Song name: Man on the Silver Mountain..............has 41 lines
# 291/458
# open file: hammerfall_lyric_291.txt
# Song name: Glory to the Brave [*]..............has 34 lines
# 292/458
# open file: hammerfall_lyric_292.txt
# Song name: The Fallen One..............has 29 lines
# 293/458
# open file: hammerfall_lyric_293.txt
# Song name: Glory to the Brave..............has 34 lines
# 294/458
# open file: hammerfall_lyric_294.txt
# Song name: Heeding the Call..............has 28 lines
# 295/458
# open file: hammerfall_lyric_295.txt
# Song name: Legacy of Kings..............has 36 lines
# 296/458
# open file: hammerfall_lyric_296.txt
# Song name: Let the Hammer Fall..............has 24 lines
# 297/458
# open file: hammerfall_lyric_297.txt
# Song name: Dreamland..............has 40 lines
# 298/458
# open file: hammerfall_lyric_298.txt
# Song name: Remember Yesterday..............has 43 lines
# 299/458
# open file: hammerfall_lyric_299.txt
# Song name: At the End of the Rainbow..............has 39 lines
# 300/458
# open file: hammerfall_lyric_300.txt
# Empty page is detected!!! Continuing to next page!
# 301/458
# open file: hammerfall_lyric_301.txt
# Song name: Stronger Than All..............has 30 lines
# 302/458
# open file: hammerfall_lyric_302.txt
# Song name: Warriors of Faith..............has 27 lines
# 303/458
# open file: hammerfall_lyric_303.txt
# Song name: The Fallen One..............has 29 lines
# 304/458
# open file: hammerfall_lyric_304.txt
# Song name: Heeding the Call..............has 28 lines
# 305/458
# open file: hammerfall_lyric_305.txt
# Song name: Legacy of Kings..............has 36 lines
# 306/458
# open file: hammerfall_lyric_306.txt
# Song name: Let the Hammer Fall..............has 24 lines
# 307/458
# open file: hammerfall_lyric_307.txt
# Song name: Dreamland..............has 40 lines
# 308/458
# open file: hammerfall_lyric_308.txt
# Song name: Remember Yesterday..............has 43 lines
# 309/458
# open file: hammerfall_lyric_309.txt
# Song name: At the End of the Rainbow..............has 39 lines
# 310/458
# open file: hammerfall_lyric_310.txt
# Empty page is detected!!! Continuing to next page!
# 311/458
# open file: hammerfall_lyric_311.txt
# Song name: Stronger Than All..............has 30 lines
# 312/458
# open file: hammerfall_lyric_312.txt
# Song name: Warriors of Faith..............has 27 lines
# 313/458
# open file: hammerfall_lyric_313.txt
# Song name: Fallen One..............has 29 lines
# 314/458
# open file: hammerfall_lyric_314.txt
# Song name: Eternal Dark..............has 24 lines
# 315/458
# open file: hammerfall_lyric_315.txt
# Song name: Any Means Necessary..............has 42 lines
# 316/458
# open file: hammerfall_lyric_316.txt
# Song name: Last Man Standing..............has 63 lines
# 317/458
# open file: hammerfall_lyric_317.txt
# Song name: Blood Bound..............has 44 lines
# 318/458
# open file: hammerfall_lyric_318.txt
# Song name: Hearts on Fire..............has 35 lines
# 319/458
# open file: hammerfall_lyric_319.txt
# Song name: Renegade..............has 34 lines
# 320/458
# open file: hammerfall_lyric_320.txt
# Song name: The Dragon Lies Bleeding..............has 36 lines
# 321/458
# open file: hammerfall_lyric_321.txt
# Song name: The Metal Age..............has 29 lines
# 322/458
# open file: hammerfall_lyric_322.txt
# Song name: Hammerfall..............has 26 lines
# 323/458
# open file: hammerfall_lyric_323.txt
# Song name: I Believe..............has 22 lines
# 324/458
# open file: hammerfall_lyric_324.txt
# Song name: Child of the Damned..............has 21 lines
# 325/458
# open file: hammerfall_lyric_325.txt
# Song name: Steel Meets Steel..............has 17 lines
# 326/458
# open file: hammerfall_lyric_326.txt
# Song name: Stone Cold..............has 16 lines
# 327/458
# open file: hammerfall_lyric_327.txt
# Song name: Unchained..............has 31 lines
# 328/458
# open file: hammerfall_lyric_328.txt
# Song name: Glory to the Brave..............has 34 lines
# 329/458
# open file: hammerfall_lyric_329.txt
# Song name: The Dragon Lies Bleeding..............has 36 lines
# 330/458
# open file: hammerfall_lyric_330.txt
# Song name: The Metal Age..............has 29 lines
# 331/458
# open file: hammerfall_lyric_331.txt
# Song name: Hammerfall..............has 23 lines
# 332/458
# open file: hammerfall_lyric_332.txt
# Song name: I Believe..............has 22 lines
# 333/458
# open file: hammerfall_lyric_333.txt
# Song name: Child of the Damned..............has 21 lines
# 334/458
# open file: hammerfall_lyric_334.txt
# Song name: Steel Meets Steel..............has 17 lines
# 335/458
# open file: hammerfall_lyric_335.txt
# Song name: Stone Cold..............has 16 lines
# 336/458
# open file: hammerfall_lyric_336.txt
# Song name: Unchained..............has 31 lines
# 337/458
# open file: hammerfall_lyric_337.txt
# Song name: Glory to the Brave..............has 34 lines
# 338/458
# open file: hammerfall_lyric_338.txt
# Song name: Stone Cold..............has 16 lines
# 339/458
# open file: hammerfall_lyric_339.txt
# Song name: Detroit Rock City..............has 41 lines
# 340/458
# open file: hammerfall_lyric_340.txt
# Song name: Always Will Be..............has 31 lines
# 341/458
# open file: hammerfall_lyric_341.txt
# Song name: The Fallen One..............has 29 lines
# 342/458
# open file: hammerfall_lyric_342.txt
# Song name: Breaking the Law..............has 22 lines
# 343/458
# open file: hammerfall_lyric_343.txt
# Song name: Remember Yesterday..............has 43 lines
# 344/458
# open file: hammerfall_lyric_344.txt
# Song name: Glory to the Brave [Radio Edit] [Edit]..............has 34 lines
# 345/458
# open file: hammerfall_lyric_345.txt
# Empty page is detected!!! Continuing to next page!
# 346/458
# open file: hammerfall_lyric_346.txt
# Song name: I Believe..............has 22 lines
# 347/458
# open file: hammerfall_lyric_347.txt
# Song name: Glory to the Brave [Album Version] [Version]..............has 34 lines
# 348/458
# open file: hammerfall_lyric_348.txt
# Song name: Hearts on Fire..............has 35 lines
# 349/458
# open file: hammerfall_lyric_349.txt
# Song name: Heeding the Call..............has 28 lines
# 350/458
# open file: hammerfall_lyric_350.txt
# Song name: Eternal Dark..............has 24 lines
# 351/458
# open file: hammerfall_lyric_351.txt
# Song name: I Want Out..............has 31 lines
# 352/458
# open file: hammerfall_lyric_352.txt
# Song name: At the End of the Rainbow..............has 39 lines
# 353/458
# open file: hammerfall_lyric_353.txt
# Song name: Man on the Silver Mountain..............has 41 lines
# 354/458
# open file: hammerfall_lyric_354.txt
# Song name: Last Man Standing..............has 63 lines
# 355/458
# open file: hammerfall_lyric_355.txt
# Song name: Natural High..............has 29 lines
# 356/458
# open file: hammerfall_lyric_356.txt
# Song name: The Fire Burns Forever..............has 29 lines
# 357/458
# open file: hammerfall_lyric_357.txt
# Song name: Any Means Necessary..............has 42 lines
# 358/458
# open file: hammerfall_lyric_358.txt
# Song name: Punish and Enslave..............has 81 lines
# 359/458
# open file: hammerfall_lyric_359.txt
# Song name: Legion..............has 31 lines
# 360/458
# open file: hammerfall_lyric_360.txt
# Song name: Hallowed Be My Name..............has 39 lines
# 361/458
# open file: hammerfall_lyric_361.txt
# Song name: No Sacrifice, No Victory..............has 24 lines
# 362/458
# open file: hammerfall_lyric_362.txt
# Song name: Bring the Hammer Down..............has 32 lines
# 363/458
# open file: hammerfall_lyric_363.txt
# Song name: One of a Kind..............has 37 lines
# 364/458
# open file: hammerfall_lyric_364.txt
# Empty page is detected!!! Continuing to next page!
# 365/458
# open file: hammerfall_lyric_365.txt
# Song name: One More Time..............has 41 lines
# 366/458
# open file: hammerfall_lyric_366.txt
# Song name: One More Time [Instrumental]..............has 41 lines
# 367/458
# open file: hammerfall_lyric_367.txt
# Song name: Warriors of Faith..............has 27 lines
# 368/458
# open file: hammerfall_lyric_368.txt
# Song name: Stronger Than All..............has 30 lines
# 369/458
# open file: hammerfall_lyric_369.txt
# Song name: Between Two Worlds..............has 26 lines
# 370/458
# open file: hammerfall_lyric_370.txt
# Song name: Glory to the Brave..............has 34 lines
# 371/458
# open file: hammerfall_lyric_371.txt
# Song name: Unchained..............has 31 lines
# 372/458
# open file: hammerfall_lyric_372.txt
# Song name: Stone Cold [Live; Bonus Track]..............has 16 lines
# 373/458
# open file: hammerfall_lyric_373.txt
# Song name: Steel Meets Steel..............has 17 lines
# 374/458
# open file: hammerfall_lyric_374.txt
# Song name: Child of the Damned..............has 21 lines
# 375/458
# open file: hammerfall_lyric_375.txt
# Song name: I Believe..............has 22 lines
# 376/458
# open file: hammerfall_lyric_376.txt
# Song name: Hammerfall [Bonus Track]..............has 23 lines
# 377/458
# open file: hammerfall_lyric_377.txt
# Song name: Metal Age [Live; Bonus Track]..............has 29 lines
# 378/458
# open file: hammerfall_lyric_378.txt
# Song name: The Dragon Lies Bleeding..............has 36 lines
# 379/458
# open file: hammerfall_lyric_379.txt
# Song name: At the End of the Rainbow..............has 39 lines
# 380/458
# open file: hammerfall_lyric_380.txt
# Song name: Remember Yesterday..............has 43 lines
# 381/458
# open file: hammerfall_lyric_381.txt
# Song name: Dreamland..............has 40 lines
# 382/458
# open file: hammerfall_lyric_382.txt
# Song name: Legacy of Kings..............has 36 lines
# 383/458
# open file: hammerfall_lyric_383.txt
# Song name: Heeding the Call..............has 28 lines
# 384/458
# open file: hammerfall_lyric_384.txt
# Song name: Hero's Return..............has 32 lines
# 385/458
# open file: hammerfall_lyric_385.txt
# Song name: The Unforgiving Blade..............has 27 lines
# 386/458
# open file: hammerfall_lyric_386.txt
# Song name: Angel of Mercy..............has 27 lines
# 387/458
# open file: hammerfall_lyric_387.txt
# Song name: Dreams Come True..............has 30 lines
# 388/458
# open file: hammerfall_lyric_388.txt
# Song name: Trail Blazers..............has 32 lines
# 389/458
# open file: hammerfall_lyric_389.txt
# Song name: Crimson Thunder..............has 26 lines
# 390/458
# open file: hammerfall_lyric_390.txt
# Song name: On the Edge of Honour..............has 28 lines
# 391/458
# open file: hammerfall_lyric_391.txt
# Song name: Never Forgive, Never Forget..............has 26 lines
# 392/458
# open file: hammerfall_lyric_392.txt
# Song name: Dominion..............has 40 lines
# 393/458
# open file: hammerfall_lyric_393.txt
# Song name: Scars of a Generation..............has 30 lines
# 394/458
# open file: hammerfall_lyric_394.txt
# Song name: Dead by Dawn..............has 46 lines
# 395/458
# open file: hammerfall_lyric_395.txt
# Song name: Bloodline..............has 41 lines
# 396/458
# open file: hammerfall_lyric_396.txt
# Song name: Testify..............has 34 lines
# 397/458
# open file: hammerfall_lyric_397.txt
# Song name: Second to One (feat. Noora Louhimo)..............has 27 lines
# 398/458
# open file: hammerfall_lyric_398.txt
# Song name: One Against the World..............has 29 lines
# 399/458
# open file: hammerfall_lyric_399.txt
# Song name: And yet I Smile..............has 40 lines
# 400/458
# open file: hammerfall_lyric_400.txt
# Song name: Second to One..............has 27 lines
# 401/458
# open file: hammerfall_lyric_401.txt
# Song name: (We Make) Sweden Rock..............has 43 lines
# 402/458
# open file: hammerfall_lyric_402.txt
# Song name: Chain of Command..............has 27 lines
# 403/458
# open file: hammerfall_lyric_403.txt
# Song name: The Way of the Warrior..............has 47 lines
# 404/458
# open file: hammerfall_lyric_404.txt
# Song name: Crazy Nights [Bonus Track]..............has 40 lines
# 405/458
# open file: hammerfall_lyric_405.txt
# Empty page is detected!!! Continuing to next page!
# 406/458
# open file: hammerfall_lyric_406.txt
# Song name: Blood Bound..............has 44 lines
# 407/458
# open file: hammerfall_lyric_407.txt
# Empty page is detected!!! Continuing to next page!
# 408/458
# open file: hammerfall_lyric_408.txt
# Song name: Threshold [Live]..............has 41 lines
# 409/458
# open file: hammerfall_lyric_409.txt
# Song name: The Dragon Lies Bleeding..............has 36 lines
# 410/458
# open file: hammerfall_lyric_410.txt
# Song name: One Against the World..............has 29 lines
# 411/458
# open file: hammerfall_lyric_411.txt
# Song name: Testify..............has 34 lines
# 412/458
# open file: hammerfall_lyric_412.txt
# Song name: Dominion..............has 40 lines
# 413/458
# open file: hammerfall_lyric_413.txt
# Song name: Stone Cold [Live; Bonus Track]..............has 16 lines
# 414/458
# open file: hammerfall_lyric_414.txt
# Song name: Scars of a Generation..............has 30 lines
# 415/458
# open file: hammerfall_lyric_415.txt
# Song name: Never Forgive, Never Forget..............has 26 lines
# 416/458
# open file: hammerfall_lyric_416.txt
# Song name: (We Make) Sweden Rock..............has 43 lines
# 417/458
# open file: hammerfall_lyric_417.txt
# Song name: The Dragon Lies Bleeding..............has 36 lines
# 418/458
# open file: hammerfall_lyric_418.txt
# Song name: Life Is Now..............has 43 lines
# 419/458
# open file: hammerfall_lyric_419.txt
# Song name: Hammerfall..............has 26 lines
# 420/458
# open file: hammerfall_lyric_420.txt
# Song name: Natural High..............has 29 lines
# 421/458
# open file: hammerfall_lyric_421.txt
# Song name: Blood Bound..............has 44 lines
# 422/458
# open file: hammerfall_lyric_422.txt
# Song name: The Metal Age..............has 29 lines
# 423/458
# open file: hammerfall_lyric_423.txt
# Song name: Steel Meets Steel..............has 17 lines
# 424/458
# open file: hammerfall_lyric_424.txt
# Song name: Stone Cold [Live; Bonus Track]..............has 16 lines
# 425/458
# open file: hammerfall_lyric_425.txt
# Song name: The Fire Burns Forever..............has 28 lines
# 426/458
# open file: hammerfall_lyric_426.txt
# Empty page is detected!!! Continuing to next page!
# 427/458
# open file: hammerfall_lyric_427.txt
# Song name: Always Will Be..............has 31 lines
# 428/458
# open file: hammerfall_lyric_428.txt
# Song name: Natural High..............has 29 lines
# 429/458
# open file: hammerfall_lyric_429.txt
# Empty page is detected!!! Continuing to next page!
# 430/458
# open file: hammerfall_lyric_430.txt
# Song name: Let the Hammer Fall [Live]..............has 24 lines
# 431/458
# open file: hammerfall_lyric_431.txt
# Song name: Dominion..............has 40 lines
# 432/458
# open file: hammerfall_lyric_432.txt
# Song name: One Against the World..............has 29 lines
# 433/458
# open file: hammerfall_lyric_433.txt
# Song name: (We Make) Sweden Rock..............has 43 lines
# 434/458
# open file: hammerfall_lyric_434.txt
# Song name: One Against the World..............has 29 lines
# 435/458
# open file: hammerfall_lyric_435.txt
# Song name: Templars of Steel..............has 31 lines
# 436/458
# open file: hammerfall_lyric_436.txt
# Song name: Steel Meets Steel..............has 17 lines
# 437/458
# open file: hammerfall_lyric_437.txt
# Song name: Heeding the Call..............has 28 lines
# 438/458
# open file: hammerfall_lyric_438.txt
# Song name: Keep the Flame Burning..............has 22 lines
# 439/458
# open file: hammerfall_lyric_439.txt
# Song name: Glory to the Brave..............has 34 lines
# 440/458
# open file: hammerfall_lyric_440.txt
# Song name: Hammerfall V1.07..............has 31 lines
# 441/458
# open file: hammerfall_lyric_441.txt
# Song name: No Mercy..............has 42 lines
# 442/458
# open file: hammerfall_lyric_442.txt
# Song name: Venerate Me..............has 24 lines
# 443/458
# open file: hammerfall_lyric_443.txt
# Song name: Not Today..............has 40 lines
# 444/458
# open file: hammerfall_lyric_444.txt
# Song name: Brotherhood..............has 38 lines
# 445/458
# open file: hammerfall_lyric_445.txt
# Song name: Live Free or Die..............has 44 lines
# 446/458
# open file: hammerfall_lyric_446.txt
# Song name: No Son of Odin..............has 44 lines
# 447/458
# open file: hammerfall_lyric_447.txt
# Song name: State of the W.I.L.D...............has 36 lines
# 448/458
# open file: hammerfall_lyric_448.txt
# Song name: Reveries..............has 50 lines
# 449/458
# open file: hammerfall_lyric_449.txt
# Song name: Hammer of Dawn..............has 36 lines
# 450/458
# open file: hammerfall_lyric_450.txt
# Song name: Too Old to Die Young..............has 40 lines
# 451/458
# open file: hammerfall_lyric_451.txt
# Song name: Templars of Steel [2020 Remix]..............has 31 lines
# 452/458
# open file: hammerfall_lyric_452.txt
# Song name: The Way of the Warrior [2020 Remix]..............has 49 lines
# 453/458
# open file: hammerfall_lyric_453.txt
# Song name: Renegade [2020 Remix]..............has 36 lines
# 454/458
# open file: hammerfall_lyric_454.txt
# Song name: Keep the Flame Burning [2020 Remix]..............has 27 lines
# 455/458
# open file: hammerfall_lyric_455.txt
# Song name: The Champion [2020 Remix]..............has 44 lines
# 456/458
# open file: hammerfall_lyric_456.txt
# Song name: A Legend Reborn [2020 Remix]..............has 42 lines
# 457/458
# open file: hammerfall_lyric_457.txt
# Song name: Destined for Glory [2020 Remix]..............has 47 lines

# %%
catalog={'song_names':song_names,
        'sentences': all_sentences}

# %%
df = pd.DataFrame(catalog, index=song_names)

# %%
df
# Out:
#                                                       song_names
# Hector's Hymn                                      Hector's Hymn  \
# Hector's Hymn                                      Hector's Hymn
# Hector's Hymn                                      Hector's Hymn
# Hector's Hymn                                      Hector's Hymn
# Hector's Hymn                                      Hector's Hymn
# ...                                                          ...
# Destined for Glory [2020 Remix]  Destined for Glory [2020 Remix]
# Destined for Glory [2020 Remix]  Destined for Glory [2020 Remix]
# Destined for Glory [2020 Remix]  Destined for Glory [2020 Remix]
# Destined for Glory [2020 Remix]  Destined for Glory [2020 Remix]
# Destined for Glory [2020 Remix]  Destined for Glory [2020 Remix]
#
#                                                                          sentences
# Hector's Hymn                    i rose from the ashes the remains of a time se...
# Hector's Hymn                    the warrior of eden found by honor these two w...
# Hector's Hymn                    on and on and on with glory he came he saw he ...
# Hector's Hymn                    he gathered his armies true he leads his templ...
# Hector's Hymn                    they sought out the dragon made the enemy blee...
# ...                                                                            ...
# Destined for Glory [2020 Remix]      but fight without honor and youre destined to
# Destined for Glory [2020 Remix]                                               fall
# Destined for Glory [2020 Remix]       fight with your heart and youre destined for
# Destined for Glory [2020 Remix]                                              glory
# Destined for Glory [2020 Remix]   but fight without soul and you will loose it all
#
# [14072 rows x 2 columns]

# %%
df['sentences'].isna().sum()
# Out:
# 0

# %%
df['song_names'].isna().sum()
# Out:
# 0

# %%
df.to_csv(f'{the_artist}.csv')
